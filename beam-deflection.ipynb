# %% [markdown]
# # Python Beam Deflection Using FEA

# %%
import numpy as np
import matplotlib.pyplot as plt
from beam import Beam
plt.style.use('classic')

# %%
endpoints = ['fixed', 'none']
forces = ['distributed', 1000, [0, 2]]

b1 = Beam(25, endpoints, forces, 2, 180e9, 0.02043)
b1.plot()
